# %%
# upload vizdoom scenario
from google.colab import files,drive
#uploaded = files.upload()
drive.mount('/content/gdrive')

# !pip install kora

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/thesis_code'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/thesis_code

# %%
# %%bash
# git add .
# git config --global user.email "kon.karageorgos.g@gmail.com"
# git config --global user.name "constant-inos"
# git commit -m 'zzz'
# git push origin main
# Out:
# [main 078f73c] zzz
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: could not read Username for 'https://github.com': No such device or address
